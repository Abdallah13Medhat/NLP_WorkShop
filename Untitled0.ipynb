# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re, string
from wordcloud import WordCloud
from collections import Counter

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
train_df = pd.read_csv("twitter_training.csv", header=None)
test_df  = pd.read_csv("twitter_test.csv", header=None)

print("Training data shape:", train_df.shape)
print("Testing data shape:", test_df.shape)

train_df.head()
# Out:
# Training data shape: (83186, 4)
# Testing data shape: (1000, 4)
#       0            1         2  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                    3
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
train_df.columns = ["id", "topic", "label", "tweet_text"]
test_df.columns  = ["id", "topic", "label", "tweet_text"]

train_df = train_df[["tweet_text", "label"]]
test_df  = test_df[["tweet_text", "label"]]

print("✅ Columns renamed successfully:")
print(train_df.head(3))
# Out:
# ✅ Columns renamed successfully:
#                                           tweet_text     label
# 0  im getting on borderlands and i will murder yo...  Positive
# 1  I am coming to the borders and I will kill you...  Positive
# 2  im getting on borderlands and i will kill you ...  Positive

# %%
plt.figure(figsize=(8,5))
sns.countplot(y='label', data=train_df, order=train_df['label'].value_counts().index)
plt.title("Label Distribution in Training Data")
plt.xlabel("Count")
plt.ylabel("Label")
plt.show()

print(train_df['label'].value_counts())
# Out:
# label
# Negative                                                                                                 25554
# Positive                                                                                                 23112
# Neutral                                                                                                  19668
# Irrelevant                                                                                               14851
#  but was and is specifically designed not to serve and protect her... time.com / 4779112 / police..."        1
# Name: count, dtype: int64

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'http\S+|www\.\S+', ' ', text)
    text = re.sub(r'@\w+', ' ', text)
    text = re.sub(r'#', ' ', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\d+', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['clean_text'] = train_df['tweet_text'].apply(clean_text)
test_df['clean_text']  = test_df['tweet_text'].apply(clean_text)

train_df.head()
# Out:
#                                           tweet_text     label  \
# 0  im getting on borderlands and i will murder yo...  Positive
# 1  I am coming to the borders and I will kill you...  Positive
# 2  im getting on borderlands and i will kill you ...  Positive
# 3  im coming on borderlands and i will murder you...  Positive
# 4  im getting on borderlands 2 and i will murder ...  Positive
#
#                                           clean_text
# 0  im getting on borderlands and i will murder yo...
# 1  i am coming to the borders and i will kill you...
# 2  im getting on borderlands and i will kill you all
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands and i will murder yo...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

bow_vectorizer = CountVectorizer(max_features=5000)
X_train_bow = bow_vectorizer.fit_transform(X_train)
X_val_bow = bow_vectorizer.transform(X_val)
X_test_bow = bow_vectorizer.transform(test_df['clean_text'])

lr_bow = LogisticRegression(max_iter=1000)
lr_bow.fit(X_train_bow, y_train)

y_pred_val = lr_bow.predict(X_val_bow)
print("BoW + Logistic Regression Performance:\n")
print(classification_report(y_val, y_pred_val))

y_pred_test = lr_bow.predict(X_test_bow)
print("\nTest Data Classification Report:\n")
print(classification_report(test_df['label'], y_pred_test))
# Out:
# BoW + Logistic Regression Performance:
#
#               precision    recall  f1-score   support
#
#   Irrelevant       0.70      0.58      0.64      2937
#     Negative       0.75      0.79      0.77      5147
#      Neutral       0.69      0.64      0.67      3903
#     Positive       0.68      0.76      0.72      4651
#
#     accuracy                           0.71     16638
#    macro avg       0.71      0.69      0.70     16638
# weighted avg       0.71      0.71      0.71     16638
#
#
# Test Data Classification Report:
#
#               precision    recall  f1-score   support
#
#   Irrelevant       0.82      0.74      0.78       172
#     Negative       0.83      0.88      0.86       266
#      Neutral       0.86      0.81      0.83       285
#     Positive       0.81      0.86      0.83       277
#
#     accuracy                           0.83      1000
#    macro avg       0.83      0.82      0.82      1000
# weighted avg       0.83      0.83      0.83      1000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_val_tfidf = tfidf_vectorizer.transform(X_val)
X_test_tfidf = tfidf_vectorizer.transform(test_df['clean_text'])

svm_tfidf = LinearSVC()
svm_tfidf.fit(X_train_tfidf, y_train)

y_pred_val_tfidf = svm_tfidf.predict(X_val_tfidf)
print("TF-IDF + SVM Performance:\n")
print(classification_report(y_val, y_pred_val_tfidf))

y_pred_test_tfidf = svm_tfidf.predict(X_test_tfidf)
print("\nTest Data Classification Report:\n")
print(classification_report(test_df['label'], y_pred_test_tfidf))
# Out:
# TF-IDF + SVM Performance:
#
#               precision    recall  f1-score   support
#
#   Irrelevant       0.69      0.57      0.63      2937
#     Negative       0.75      0.78      0.77      5147
#      Neutral       0.66      0.66      0.66      3903
#     Positive       0.71      0.75      0.73      4651
#
#     accuracy                           0.71     16638
#    macro avg       0.70      0.69      0.69     16638
# weighted avg       0.71      0.71      0.71     16638
#
#
# Test Data Classification Report:
#
#               precision    recall  f1-score   support
#
#   Irrelevant       0.79      0.70      0.74       172
#     Negative       0.78      0.88      0.83       266
#      Neutral       0.85      0.76      0.80       285
#     Positive       0.81      0.84      0.83       277
#
#     accuracy                           0.81      1000
#    macro avg       0.81      0.80      0.80      1000
# weighted avg       0.81      0.81      0.81      1000

# %%
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
tokenizer.fit_on_texts(train_df['clean_text'])

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_val_seq = tokenizer.texts_to_sequences(X_val)
X_test_seq = tokenizer.texts_to_sequences(test_df['clean_text'])

max_len = 50
X_train_pad = pad_sequences(X_train_seq, maxlen=max_len, padding='post')
X_val_pad = pad_sequences(X_val_seq, maxlen=max_len, padding='post')
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len, padding='post')

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_val_enc = le.transform(y_val)
y_test_enc = le.transform(test_df['label'])

model = Sequential([
    Embedding(10000, 128, input_length=max_len),
    LSTM(128, dropout=0.3, recurrent_dropout=0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(len(le.classes_), activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train_pad, y_train_enc, validation_data=(X_val_pad, y_val_enc), epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1040/1040 ━━━━━━━━━━━━━━━━━━━━ 125s 117ms/step - accuracy: 0.2876 - loss: 1.3931 - val_accuracy: 0.3094 - val_loss: 1.3669
# Epoch 2/5
# 1040/1040 ━━━━━━━━━━━━━━━━━━━━ 133s 109ms/step - accuracy: 0.3103 - loss: 1.3608 - val_accuracy: 0.5145 - val_loss: 1.1248
# Epoch 3/5
# 1040/1040 ━━━━━━━━━━━━━━━━━━━━ 114s 110ms/step - accuracy: 0.5770 - loss: 1.0175 - val_accuracy: 0.7280 - val_loss: 0.7215
# Epoch 4/5
# 1040/1040 ━━━━━━━━━━━━━━━━━━━━ 113s 109ms/step - accuracy: 0.7737 - loss: 0.6139 - val_accuracy: 0.7860 - val_loss: 0.5770
# Epoch 5/5
# 1040/1040 ━━━━━━━━━━━━━━━━━━━━ 147s 114ms/step - accuracy: 0.8400 - loss: 0.4383 - val_accuracy: 0.8131 - val_loss: 0.5088

# %%
y_pred_test_lstm = model.predict(X_test_pad)
y_pred_labels = np.argmax(y_pred_test_lstm, axis=1)

unique_test_labels = np.unique(y_test_enc)
target_names_subset = le.inverse_transform(unique_test_labels)

print("LSTM Model Performance:\n")
print(classification_report(y_test_enc, y_pred_labels, labels=unique_test_labels, target_names=target_names_subset))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# LSTM Model Performance:
#
#               precision    recall  f1-score   support
#
#   Irrelevant       0.85      0.91      0.88       172
#     Negative       0.93      0.95      0.94       266
#      Neutral       0.94      0.91      0.93       285
#     Positive       0.93      0.90      0.92       277
#
#     accuracy                           0.92      1000
#    macro avg       0.91      0.92      0.91      1000
# weighted avg       0.92      0.92      0.92      1000

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title("Accuracy over epochs")

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Loss over epochs")
plt.show()
